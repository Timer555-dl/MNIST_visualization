# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras import Input
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from scipy.special import softmax

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
input_tensor = Input(shape=(train_images.shape[1], train_images.shape[2],))
l1 = layers.Flatten()(input_tensor)
l2 = layers.Dense(512, activation='relu')(l1)
number = layers.Dense(10, activation='softmax')(l2)

model = Model(input_tensor, number)
model.compile(optimizer='rmsprop', 
              loss='categorical_crossentropy', metrics=['accuracy'])
callbacks = [tf.keras.callbacks.TensorBoard(log_dir='C:\\Users\\S3823370\\Documents\\GitHub\\MNIST_visualization\\Tensorboard', 
                                            histogram_freq=1, 
                                            embeddings_freq=1)]

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs=5, batch_size=128, callbacks=callbacks)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 33s 552us/sample - loss: 0.2640 - accuracy: 0.9795
# Epoch 2/5
# 60000/60000 [==============================] - 33s 543us/sample - loss: 0.2738 - accuracy: 0.9818
# Epoch 3/5
# 60000/60000 [==============================] - 32s 540us/sample - loss: 0.2261 - accuracy: 0.9844
# Epoch 4/5
# 60000/60000 [==============================] - 32s 530us/sample - loss: 0.2291 - accuracy: 0.9853
# Epoch 5/5
# 60000/60000 [==============================] - 32s 540us/sample - loss: 0.2170 - accuracy: 0.9864

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 23s 2ms/sample - loss: 0.5885 - accuracy: 0.9687

# %%
loss = history.history['loss']
acc = history.history['accuracy']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, acc, 'r', label='Training acc')
plt.title('Training loss and accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
all_l2_bias = np.asanyarray(model.layers[2].get_weights()[1])
print(all_l2_bias.shape)
all_l2_weights = np.asanyarray(model.layers[2].get_weights()[0]).T
print(all_l2_weights.shape)
all_l2_weights_map = plt.matshow(all_l2_weights)
plt.colorbar(all_l2_weights_map)
# Out:
# (512,)
# (512, 784)

# %%
# n_image = 1000
n_image = 4
pred_test = train_images[n_image].reshape(1, train_images.shape[1], 
                                          train_images.shape[2])
prediction = model.predict(pred_test)
print(prediction)
print(np.argmax(prediction))
print(np.argmax(train_labels[n_image]))
plt.matshow(train_images[n_image])
# Out:
# [[0.0000000e+00 0.0000000e+00 0.0000000e+00 1.2522252e-30 2.2932125e-27
#   0.0000000e+00 0.0000000e+00 1.2019857e-23 1.7943148e-34 1.0000000e+00]]
# 9
# 9

# %%
a_1 = train_images[n_image].reshape(train_images.shape[1]*
                                    train_images.shape[2])
z_2 = all_l2_weights@a_1 + all_l2_bias
z_2[z_2<0] = 0
a_2 = z_2
a_2_for_plt = z_2.reshape(16, 32)
a_2_plt = plt.matshow(a_2_for_plt)
plt.colorbar(a_2_plt)
max_activition = np.argmax(a_2)
print(max_activition)
# Out:
# 3

# %%
n_perc = max_activition
single_l2_weights = all_l2_weights[n_perc].reshape(train_images.shape[1], 
                                                   train_images.shape[2])
single_l2_weights_map = plt.matshow(single_l2_weights)
plt.colorbar(single_l2_weights_map)
single_l2_weights.shape
# Out:
# (28, 28)

# %%
wa = train_images[n_image]*single_l2_weights + all_l2_bias[n_perc]
wa[wa<0] = 0
wa_plt = plt.matshow(wa)
plt.colorbar(wa_plt)

# %%
z = np.sum(wa) + all_l2_bias[n_perc]
print(z)
# Out:
# 669.57745

# %%
all_number_bias = np.asanyarray(model.layers[3].get_weights()[1])
print(all_number_bias.shape)
all_number_weights = np.asanyarray(model.layers[3].get_weights()[0]).T
print(all_number_weights.shape)
# Out:
# (10,)
# (10, 512)

# %%
z_3 = all_number_weights@a_2 + all_number_bias
z_3 = softmax(z_3)
print(np.argmax(z_3))
print(z_3)
# Out:
# 9
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 1.2522253e-30 2.2932477e-27
#  0.0000000e+00 0.0000000e+00 1.2019857e-23 1.7943422e-34 1.0000000e+00]

# %%
n_image_set = np.array([8, 7, 2, 0, 18, 52, 17, 4])
sum_pixels = train_images[n_image_set]
sum_pixels[sum_pixels<128] = 0
sum_pixels[sum_pixels>=128] = 1
sum_pixels = sum_pixels.sum(axis=0)
pixels_plt = plt.matshow(sum_pixels)
plt.colorbar(pixels_plt)

# %%
non_zeros_images = train_images[train_labels[:,9]!=1]
non_zeros_images[non_zeros_images<128] = 0
non_zeros_images[non_zeros_images>=128] = 1
non_zeros_images = non_zeros_images.sum(axis=0)
pixels_plt = plt.matshow(non_zeros_images)
plt.colorbar(pixels_plt)
